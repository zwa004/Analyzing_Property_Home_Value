# %%
import pandas as pd
import numpy as np

# %%
#import data
df = pd.read_csv('datafiniti_clean_prices_df.csv')
df
# Out:
#                        id                      address       city country  \
# 0    AXDUGAcDe6LJWXYXc1q1         1055 Zophi St Unit A  Nashville      US
# 1    AW_5qxNG0x_BgD4e2_BK          2317 Pennington Ave  Nashville      US
# 2    2ybOPnUBA7mjcpg9OxcN                110 7th Ave N  Nashville      US
# 3    AXCfxouC2qQdVO6NpfHb               129 43rd Ave N  Nashville      US
# 4    AXEElvfPLZfAPClVV0JG        922 Thomas Ave Unit B  Nashville      US
# ..                    ...                          ...        ...     ...
# 555  AWtV69sl0x_BgD4eB5rZ            1600 Lebanon Pike  Nashville      US
# 556  lnuD73oBcI676yQnEzZ3      4602 Georgia Ave Unit A  Nashville      US
# 557  AWShYG7bjCNrmMAsi1gp                3817 Bryce Rd  Nashville      US
# 558  _S01THUBA7mjcpg9Pn85  500 Paragon Mills Rd Apt H6  Nashville      US
# 559  AWUdxxxuAXxH_fqQRegc              222 Orlando Ave  Nashville      US
#
#                 dateAdded           dateUpdated  floorSizeValue   latitude  \
# ...

# %%
df.dtypes
# Out:
# id                     object
# address                object
# city                   object
# country                object
# dateAdded              object
# dateUpdated            object
# floorSizeValue        float64
# latitude              float64
# longitude             float64
# lotSizeValue          float64
# lotSizeUnit            object
# mlsNumber              object
# neighborhoods          object
# numBathroom           float64
# numBedroom            float64
# numFloor              float64
# parking                object
# postalCode             object
# propertyType           object
# yearBuilt             float64
# price                   int64
# pricePerSquareFoot    float64
# dtype: object

# %%
#check for nan values
df.isna().sum()
# Out:
# id                      0
# address               306
# city                    0
# country                 0
# dateAdded               0
# dateUpdated             0
# floorSizeValue        354
# latitude                1
# longitude               1
# lotSizeValue          334
# lotSizeUnit           334
# mlsNumber             319
# neighborhoods         387
# numBathroom            29
# numBedroom             22
# numFloor              341
# parking               332
# postalCode            302
# propertyType            0
# yearBuilt             318
# price                   0
# pricePerSquareFoot    361
# dtype: int64

# %%
#check for any rows with all columns nan
df.isna().all(axis=1).sum()
# Out:
# 0

# %%
#identify the rows for price column where price is less than $10,000
df[df['price'] < 10000]
# Out:
#                        id                address       city country  \
# 6    8A9bKXgB5p3ULnC0_ywP  508 36th Ave N Unit B  Nashville      US
# 41   AW6fn2qqY7ir8pkrNkpS            HIGHWAY 100  NASHVILLE      US
# 52   0f7KDHQBzBVh0wsvSBW_     1502A Kirkwood Ave  Nashville      US
# 98   qoyDeoAB5p3ULnC0FHTT                    NaN  Nashville      US
# 104  yCznMXIBT9R6xkeZ9buf        1305 Clinton St  Nashville      US
# ..                    ...                    ...        ...     ...
# 457  AW7JndpSY7ir8pkrSkM-         1226 N 2nd Ave  Nashville      US
# 463  vnUxeoAByN4LkFz_qOmq                    NaN  Nashville      US
# 478  QHUfeoAByN4LkFz_Xugi                    NaN  Nashville      US
# 488  AWl58fvNAXxH_fqQG9-L      6448 Sunnywood Dr  Nashville      US
# 548  AXECpEKygJi9zA4D1ari        1925 16th Ave N  Nashville      US
#
#                 dateAdded           dateUpdated  floorSizeValue   latitude  \
# ...

# %%
df.propertyType.unique()
# Out:
# array(['Single Family Dwelling', 'Condo', 'Commercial', 'Other', 'Land',
#        'Multi-Family Dwelling', 'Townhouse', 'Industrial', 'Room',
#        'Villa', 'Guesthouse', 'Loft', 'Cabin', 'Bungalow', 'Hotel',
#        'Cottage', 'Apartment', 'Retail'], dtype=object)

# %%
df.propertyType.nunique()
# Out:
# 18

# %%
df.dropna()
# Out:
#                        id                      address       city country  \
# 1    AW_5qxNG0x_BgD4e2_BK          2317 Pennington Ave  Nashville      US
# 3    AXCfxouC2qQdVO6NpfHb               129 43rd Ave N  Nashville      US
# 8    AWTUti0zAXxH_fqQAyZ1          859 Brook Hollow Rd  Nashville      US
# 10   aRpE1XgB5p3ULnC0uqjp        611 39th Ave N Unit B  Nashville      US
# 12   AWtVvgRZcWockGYkZBkQ          212 Belle Chasse Ct  Nashville      US
# ..                    ...                          ...        ...     ...
# 554  AW2F2dB0hcmU2WcKbL_n           1997 Nashboro Blvd  Nashville      US
# 555  AWtV69sl0x_BgD4eB5rZ            1600 Lebanon Pike  Nashville      US
# 557  AWShYG7bjCNrmMAsi1gp                3817 Bryce Rd  Nashville      US
# 558  _S01THUBA7mjcpg9Pn85  500 Paragon Mills Rd Apt H6  Nashville      US
# 559  AWUdxxxuAXxH_fqQRegc              222 Orlando Ave  Nashville      US
#
#                 dateAdded           dateUpdated  floorSizeValue   latitude  \
# ...
